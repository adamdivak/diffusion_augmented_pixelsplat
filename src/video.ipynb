# %% [markdown]
# This notebook is to make a video grid

# %%
import os
from pathlib import Path
import torch
import json
from torch import Tensor
from jaxtyping import Float, UInt8
from io import BytesIO
import torchvision.transforms as tf
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm
import matplotlib.image as mpimg
import cv2
import numpy as np
import glob

# %%
# Directories of the real data
video_index_path = "/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/assets/evaluation_index_re10k_video.json"
root = Path('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full')
# root = Path('/teamspace/studios/re10k_data_prep/re10k')
data_stages = ["test"]

# Directories of the generated data such that the folders within are the room keys
# gen_root = Path('../output/images/test_re10k')
gen_root = Path('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_test_hard_more/re10k')

# %%
# number of videos you want to produce
num_vid = 5

# %% [markdown]
# The code below is to save the real images from the torch files into a folder

# %%
merged_index = {}
path_to_torch = []

for data_stage in data_stages:
    # Load the root's index.
    # p = Path("/teamspace/studios/re10k_data_prep/re10k/test/index.json")
    with (root / data_stage / "index.json").open("r") as f:
    # with (p).open("r") as f:
        index = json.load(f)    
    for k, v in index.items():
        path = Path(root / data_stage / v)
        index[k] = path
        if path not in path_to_torch:
            path_to_torch.append(path)
    # index = {k: Path(root / data_stage / v) for k, v in index.items()}

    # The constituent datasets should have unique keys.
    assert not (set(merged_index.keys()) & set(index.keys()))

    # Merge the root's index into the main index.
    merged_index = {**merged_index, **index}

print(merged_index)
print(f"#rooms: {len(merged_index.keys())}")
print(path_to_torch)
print(f"#torch files: {len(path_to_torch)}")
# ../datasets/re10k/test
# Out:
# {'f3a2f438945382c6': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), '750ddf09bd6d1eab': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), '9d4d95c939426580': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), '7336669f60753832': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), '73de8e1e19c1857a': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), 'fbb8d7a56a6d5741': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), '54be94f158023eea': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), 'cd3062c26ed06209': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), '3f33ed2971149ea0': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), '8bd3923459d18567': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), 'a2f517ba7adea803': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), '58b818a3eab9dc91': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), 'aa9df415be64168f': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), '1a6719eb1ee63e65': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), 'cd8a394c76de9608': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), '42d8b53a15001cd5': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), 'eb626dd19cb7459c': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), '1b65111d34f57bb0': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), 'b6279c4e184cd336': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), '0286d2ed56e8f107': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), 'c86601fe5e2141c4': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), 'c412289a16716a8a': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), '7fa1d85dba913128': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), '615a7cd0a6777887': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), '11491a312c6b8f58': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), '1a22c18ef654437d': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000290.torch'), '21a23c81331b0027': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000290.torch'), '67300e41773c1a44': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000290.torch'), 'aae8dd571bbfee04': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000290.torch'), '9ccfd60ef2a71655': PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/ ...
# #rooms: 7286
# [PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000103.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000138.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000290.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000205.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000404.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000058.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000132.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000460.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000107.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000309.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000167.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000351.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000207.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000242.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000049.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000459.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000151.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000391.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000327.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000536.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000498.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000343.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000141.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000244.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000146.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000419.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000000.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000059.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000376.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000066.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000506.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000230.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000085.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000461.torch'), PosixPath('/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/datasets/re10k_full/test/000165.torch'), PosixPath ...
# #torch files: 543

# %%
tensor = tf.ToTensor()

def convert_images(images: list[UInt8[Tensor, "..."]],) -> Float[Tensor, "batch 3 height width"]:
    torch_images = []
    for image in images:
        image = Image.open(BytesIO(image.numpy().tobytes()))
        torch_images.append(tensor(image))
    return torch.stack(torch_images)

def center_crop(
    images: Float[Tensor, "*#batch c h w"],
    shape: tuple[int, int],
) -> tuple[
    Float[Tensor, "*#batch c h_out w_out"],  # updated images
]:
    *_, h_in, w_in = images.shape
    h_out, w_out = shape
    # print(h_in, w_in, h_out, w_out)

    # Note that odd input dimensions induce half-pixel misalignments.
    row = (h_in - h_out) // 2
    col = (w_in - w_out) // 2

    # Center-crop the image.
    images = images[..., :, row : row + h_out, col : col + w_out]

    return images

def save_images(path_to_torch, out_dir):
    out_dir = Path(out_dir)
    out_dir.mkdir(exist_ok=True, parents=True)

    # num_rooms = sum(len(torch.load(path)) for path in path_to_torch)
    # print(f"Total amount of rooms: {num_rooms}")

    n = 0

    keys = []

    for path in path_to_torch:
        chunk = torch.load(path)
        for room in tqdm(chunk, desc="Processing rooms", unit="room"):

            print(f"n: {n}")

            if n >= num_vid:
                break

            key = room["key"]
            keys.append(key)
            print(key)

            images = room["images"]
            context_images = convert_images(images)

            room_path = out_dir / Path(key)
            room_path.mkdir(exist_ok=True, parents=True)

            for i, image in enumerate(context_images):
                # img = center_crop(image, (256, 256))
                img = center_crop(image, (360, 360))
                # break
                image_array = img.permute(1, 2, 0).numpy()
                image_array = (image_array * 255).astype('uint8')
                plt.imsave(f'{room_path}/{i}.png', image_array)
            
            n += 1

        if n >= num_vid:
            break
        # break
    # break

    return keys

# %%
# Takes around 3 min
# keys = save_images(path_to_torch, "/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_full")

# %% [markdown]
# Next cell is to create the image grids of ground truth and generated images

# %%
def make_img_grid(real_dir, gen_dir, output_dir):
    with open(video_index_path, 'r') as file:
        video_index = json.load(file)

    for key_dir in tqdm(gen_dir.iterdir(), desc='Processing directories'):
        if not key_dir.suffix.lower() == '.json':
            key = key_dir.stem
            output_path = Path(output_dir + f"/{key}")
            output_path.mkdir(exist_ok=True, parents=True)

            target_images = video_index[key]['target'] #[-46:] # Hardcoded for now

            for i, _ in enumerate((key_dir / Path("color")).iterdir()):
                # j = target_images[i]
                gen_img_path = key_dir / Path("color") / Path(f"{i:06d}.png")
                # real_img_path = Path(real_dir) / Path(key) / Path(str(j) + ".png")
                real_img_path = Path(real_dir) / Path(key) / Path("target") / Path(f"{i:06d}.png")

                fig, axes = plt.subplots(1, 2, figsize=(10, 5)) 

                # Display real image
                real_img = mpimg.imread(real_img_path)
                axes[0].imshow(real_img)
                axes[0].axis('off') 
                axes[0].set_title('Ground Truth')

                # Display generated image
                gen_img = mpimg.imread(gen_img_path)
                axes[1].imshow(gen_img)
                axes[1].axis('off')  
                axes[1].set_title('PixelSplat') # Hardcoded for now

                plt.subplots_adjust(wspace=0.05)
                plt.savefig(output_path / Path(f"{str(i)}.png"), bbox_inches='tight')
                plt.close(fig)

            # break for testing for just one room
            # break

# %%
make_img_grid(gen_root, gen_root, "/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid")
# Out:
# Processing directories: 0it [00:00, ?it/s]
# Processing directories: 0it [02:06, ?it/s]

# %% [markdown]
# And now create a video out of those image grids

# %%
def create_video(path_imgs, output_path, framerate=30):
    for room in Path(path_imgs).iterdir():  
        key = room.stem
        output_dir = Path(output_path)
        output_dir.mkdir(exist_ok=True, parents=True)


        img_array = []
        # for filename in glob.glob(f'{path_imgs}/{key}/*.png'):
        i = 0
        for _ in (Path(path_imgs)/Path(key)).iterdir():
            filename = path_imgs + "/" + key + f"/{i}.png"
            # print(filename)
            img = cv2.imread(filename)
            height, width, _ = img.shape
            size = (width,height)
            img_array.append(img)
            i += 1

        out = cv2.VideoWriter(f'{output_path}/{key}.avi',cv2.VideoWriter_fourcc(*'DIVX'), framerate, size)

        for i in range(len(img_array)):
            out.write(img_array[i])

        out.release()
   

create_video("/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid", 
            "/teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_video_grid")
# Out:
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/0.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/1.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/2.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/3.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/4.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/5.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/6.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/7.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/8.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/9.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/10.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/11.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/12.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/13.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/14.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/15.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/16.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/17.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/18.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/19.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/20.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/21.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/22.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/23.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/24.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/25.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/26.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/27.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/28.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/29.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/30.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/31.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/32.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/33.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/34.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/35.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/36.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/37.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/38.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/39.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/40.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/41.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/42.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/43.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/44.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/45.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/46.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/47.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/48.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/49.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/50.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/51.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/52.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/53.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/54.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/55.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/56.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/57.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/58.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/59.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/60.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/61.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/62.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/63.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/64.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/65.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/66.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/67.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/68.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/69.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/70.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/71.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/72.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/73.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/74.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/75.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/76.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/77.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/78.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/79.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/80.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/81.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/82.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/83.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/84.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/85.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/86.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/87.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/88.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/89.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/90.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/91.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/92.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/93.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/94.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/95.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/96.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/97.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/98.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/99.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/100.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/101.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/102.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/103.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/104.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/105.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/106.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/107.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/108.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/109.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/110.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/111.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/112.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/113.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/114.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/115.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/116.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/117.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/118.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/119.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/120.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/121.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/122.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/123.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/124.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/125.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/126.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/127.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/128.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/129.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/130.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/131.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/132.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/133.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/134.png
# /teamspace/studios/this_studio/diffusion-augmented-pixelsplat/outputs/re10k_img_grid/1214f2a11a9fc1ed/135.png

# %% [markdown]
# Generating videos for re10k_pixelsplat_hard

# %%
# from datasets import load_dataset
# from PIL import Image

# dataset = load_dataset("Wouter01/re10k_pixelsplat_hard", split="test")
# Out:
# Resolving data files:   0%|          | 0/36 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/36 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/36 [00:00<?, ?files/s]
# Downloading data:   0%|          | 0.00/466M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/476M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/465M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/466M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/106275 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/11489 [00:00<?, ? examples/s]
